# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('owid-covid-data.csv')

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
col_del=[]
for i in df.columns:
    if df[i].isna().sum()<len(df)//2:
        col_del.append(i)

# %%
col_del
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_units',
#  'stringency_index',
#  'population',
#  'population_density',
#  'median_age',
#  'aged_65_older',
#  'aged_70_older',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'cardiovasc_death_rate',
#  'diabetes_prevalence',
#  'female_smokers',
#  'male_smokers',
#  'hospital_beds_per_thousand',
#  'life_expectancy',
#  'human_development_index']

# %%
for i in df.columns:
    if i not in col_del:
        df.drop([i],axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# iso_code                               0
# continent                           3895
# location                               0
# date                                   0
# total_cases                         1584
# new_cases                           1586
# new_cases_smoothed                  2587
# total_deaths                       11042
# new_deaths                         10884
# new_deaths_smoothed                 2587
# total_cases_per_million             2009
# new_cases_per_million               2011
# new_cases_smoothed_per_million      3007
# total_deaths_per_million           11454
# new_deaths_per_million             11296
# new_deaths_smoothed_per_million     3007
# reproduction_rate                  15306
# new_tests_smoothed                 38047
# new_tests_smoothed_per_thousand    38047
# positive_rate                      39369
# tests_units                        36663
# stringency_index                   11547
# population                           496
# ...

# %%
df.drop(['new_tests_smoothed','new_tests_smoothed_per_thousand','positive_rate','tests_units','extreme_poverty',
        'new_cases_smoothed','female_smokers','male_smokers'],axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# iso_code                               0
# continent                           3895
# location                               0
# date                                   0
# total_cases                         1584
# new_cases                           1586
# total_deaths                       11042
# new_deaths                         10884
# new_deaths_smoothed                 2587
# total_cases_per_million             2009
# new_cases_per_million               2011
# new_cases_smoothed_per_million      3007
# total_deaths_per_million           11454
# new_deaths_per_million             11296
# new_deaths_smoothed_per_million     3007
# reproduction_rate                  15306
# stringency_index                   11547
# population                           496
# population_density                  5420
# median_age                          7649
# aged_65_older                       8477
# aged_70_older                       8055
# gdp_per_capita                      7359
# ...

# %%
df.drop(['new_deaths','new_cases_smoothed_per_million','new_deaths_per_million'],axis=1,
       inplace=True)

# %%
df['continent'].fillna('World',inplace=True)

# %%
df.drop(['iso_code'],axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# continent                              0
# location                               0
# date                                   0
# total_cases                         1584
# new_cases                           1586
# total_deaths                       11042
# new_deaths_smoothed                 2587
# total_cases_per_million             2009
# new_cases_per_million               2011
# total_deaths_per_million           11454
# new_deaths_smoothed_per_million     3007
# reproduction_rate                  15306
# stringency_index                   11547
# population                           496
# population_density                  5420
# median_age                          7649
# aged_65_older                       8477
# aged_70_older                       8055
# gdp_per_capita                      7359
# cardiovasc_death_rate               6761
# diabetes_prevalence                 5791
# hospital_beds_per_thousand         13043
# life_expectancy                     4046
# ...

# %%
for i in df.columns:
    if df[i].isna().sum()>0:
        df[i].fillna(df[i].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# continent                          0
# location                           0
# date                               0
# total_cases                        0
# new_cases                          0
# total_deaths                       0
# new_deaths_smoothed                0
# total_cases_per_million            0
# new_cases_per_million              0
# total_deaths_per_million           0
# new_deaths_smoothed_per_million    0
# reproduction_rate                  0
# stringency_index                   0
# population                         0
# population_density                 0
# median_age                         0
# aged_65_older                      0
# aged_70_older                      0
# gdp_per_capita                     0
# cardiovasc_death_rate              0
# diabetes_prevalence                0
# hospital_beds_per_thousand         0
# life_expectancy                    0
# human_development_index            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
con_le=LabelEncoder()
loc_le=LabelEncoder()
df['continent']=con_le.fit_transform(df['continent'])
df['location']=con_le.fit_transform(df['location'])

# %%
date=[]
year=[]
month=[]
day=[]
for i in range(len(df)):
    date=df['date'].split('-')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79880 entries, 0 to 79879
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   continent                        79880 non-null  int32
#  1   location                         79880 non-null  int32
#  2   date                             79880 non-null  object
#  3   total_cases                      79880 non-null  float64
#  4   new_cases                        79880 non-null  float64
#  5   total_deaths                     79880 non-null  float64
#  6   new_deaths_smoothed              79880 non-null  float64
#  7   total_cases_per_million          79880 non-null  float64
#  8   new_cases_per_million            79880 non-null  float64
#  9   total_deaths_per_million         79880 non-null  float64
#  10  new_deaths_smoothed_per_million  79880 non-null  float64
# ...

# %%
import seaborn as sns
cols=['new_cases','population_density','total_deaths','new_deaths_smoothed','total_cases_per_million']
sns.pairplot(df[cols])
plt.show()

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
c=['total_cases','total_deaths','new_deaths_smoothed','population','continent']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %%
X=df['new_deaths_smoothed'].values.reshape(-1, 1)
y=df['new_cases'].values.reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler() 
sc_y = StandardScaler() 
X_std = sc_x.fit_transform(X) 
y_std = sc_y.fit_transform(y) 
lr = LinearRegression() 
lr.fit(X_std, y_std)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.25)

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print('mse: %.3f, mae: %.3f' % (mse, mae))
# Out:
# mse: 166944851.845, mae: 2535.054

# %%
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
rf_pred=rf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print('mse: %.3f, mae: %.3f' % (mse, mae))

# %%
plt.scatter(X_train,y_train,c='blue')
plt.plot(X_train,lr.predict(X_train),color='red')
plt.show()
